# %%
import pandas as pd
weather = pd.read_csv("D:/paper/C/Weatherdata/HourlyB.csv", index_col="date")

# %%
weather
# Out:
#             hour  دید افقی  cloudy  wind direction  wind speed  temp  \
# date
# 1/1/2013       0       5.0       5              80           2  -3.4
# 1/1/2013       3       8.0       1              90           3  -5.0
# 1/1/2013       6      25.0       0              90           7  -2.6
# 1/1/2013       9      25.0       0              70           3   1.0
# 1/1/2013      12      25.0       0              70           6   0.6
# ...          ...       ...     ...             ...         ...   ...
# 12/31/2017     9      20.0       0              20           2  13.3
# 12/31/2017    12      20.0       0             250           3  13.8
# 12/31/2017    15      20.0       0              10           2   6.7
# 12/31/2017    18      15.0       0               0           0   4.0
# 12/31/2017    21      15.0       0              60           2   5.0
#
#             dew point    QFE     QFF  حداكثر دما  ...  rel_humid  ارتفاع برف  \
# date                                              ...
# 1/1/2013         -3.8  914.4  1031.6         NaN  ...         97         NaN
# 1/1/2013         -6.3  915.7  1033.7         NaN  ...         90         NaN
# 1/1/2013         -5.1  916.9  1034.8         NaN  ...         83           0
# 1/1/2013         -5.4  915.7  1032.5         NaN  ...         62         NaN
# 1/1/2013         -6.0  914.7  1031.9         NaN  ...         61         NaN
# ...               ...    ...     ...         ...  ...        ...         ...
# 12/31/2017       -6.8  909.4  1021.4         NaN  ...         24         NaN
# 12/31/2017       -7.0  908.5  1020.5         NaN  ...         23         NaN
# 12/31/2017       -7.8  909.0  1023.1        14.1  ...         35         NaN
# 12/31/2017       -9.0  909.4  1023.0         NaN  ...         38         NaN
# 12/31/2017       -8.9  909.1  1021.0         NaN  ...         36         NaN
#
#             سريعترين باد)سمت( سريعترين باد)سرعت(  دمای اعماق خاک(5cm)  \
# date
# 1/1/2013                  NaN                NaN                  NaN
# 1/1/2013                  NaN                NaN                 -0.6
# 1/1/2013                  NaN                NaN                  NaN
# 1/1/2013                  NaN                NaN                  0.0
# 1/1/2013                  NaN                NaN                  NaN
# ...                       ...                ...                  ...
# 12/31/2017                NaN                NaN                 10.8
# 12/31/2017                NaN                NaN                  NaN
# 12/31/2017                NaN                NaN                  9.0
# 12/31/2017                NaN                NaN                  NaN
# 12/31/2017               60.0                6.0                  NaN
#
#            دمای اعماق خاک(10cm)  دمای اعماق خاک(20cm)  دمای اعماق خاک(30)  \
# date
# 1/1/2013                    NaN                   NaN                 NaN
# 1/1/2013                    0.8                   2.8                 4.2
# 1/1/2013                    NaN                   NaN                 NaN
# 1/1/2013                    1.0                   3.0                 4.4
# 1/1/2013                    NaN                   NaN                 NaN
# ...                         ...                   ...                 ...
# 12/31/2017                  7.2                   7.2                10.2
# 12/31/2017                  NaN                   NaN                 NaN
# 12/31/2017                 10.2                   9.4                10.2
# 12/31/2017                  NaN                   NaN                 NaN
# 12/31/2017                  NaN                   NaN                 NaN
#
#             دمای اعماق خاک(50cm)  دمای اعماق خاک100cm)
# date
# 1/1/2013                     NaN                   NaN
# 1/1/2013                     7.4                  12.6
# 1/1/2013                     NaN                   NaN
# 1/1/2013                     7.2                  12.6
# 1/1/2013                     NaN                   NaN
# ...                          ...                   ...
# 12/31/2017                  12.0                  15.6
# 12/31/2017                   NaN                   NaN
# 12/31/2017                  11.8                  15.8
# 12/31/2017                   NaN                   NaN
# 12/31/2017                   NaN                   NaN
#
# [14608 rows x 24 columns]

# %%
null_pct=weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
weather.apply(pd.isnull).sum()
# Out:
# hour                           0
# دید افقی                       0
# cloudy                         0
# wind direction                 0
# wind speed                     0
# temp                           0
# dew point                      0
# QFE                            0
# QFF                            0
# حداكثر دما                 12782
# حداقل دما دماي سطح زمين    12782
# حداقل دماي سطح زمين        12782
# ساعات آفتابي               12782
# بارندگي                    12782
# rel_humid                      0
# ارتفاع برف                 12782
# سريعترين باد)سمت(          12782
# سريعترين باد)سرعت(         12782
# دمای اعماق خاک(5cm)         9130
# دمای اعماق خاک(10cm)        9130
# دمای اعماق خاک(20cm)        9130
# دمای اعماق خاک(30)          9130
# دمای اعماق خاک(50cm)        9130
# دمای اعماق خاک100cm)        9130
# dtype: int64

# %%
null_pct
# Out:
# hour                       0.000
# دید افقی                   0.000
# cloudy                     0.000
# wind direction             0.000
# wind speed                 0.000
# temp                       0.000
# dew point                  0.000
# QFE                        0.000
# QFF                        0.000
# حداكثر دما                 0.875
# حداقل دما دماي سطح زمين    0.875
# حداقل دماي سطح زمين        0.875
# ساعات آفتابي               0.875
# بارندگي                    0.875
# rel_humid                  0.000
# ارتفاع برف                 0.875
# سريعترين باد)سمت(          0.875
# سريعترين باد)سرعت(         0.875
# دمای اعماق خاک(5cm)        0.625
# دمای اعماق خاک(10cm)       0.625
# دمای اعماق خاک(20cm)       0.625
# دمای اعماق خاک(30)         0.625
# دمای اعماق خاک(50cm)       0.625
# دمای اعماق خاک100cm)       0.625
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < .05]

# %%
valid_columns
# Out:
# Index(['hour', 'دید افقی', 'cloudy', 'wind direction', 'wind speed', 'temp',
#        'dew point', 'QFE', 'QFF', 'rel_humid'],
#       dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#             hour  دید افقی  cloudy  wind direction  wind speed  temp  \
# date
# 1/1/2013       0       5.0       5              80           2  -3.4
# 1/1/2013       3       8.0       1              90           3  -5.0
# 1/1/2013       6      25.0       0              90           7  -2.6
# 1/1/2013       9      25.0       0              70           3   1.0
# 1/1/2013      12      25.0       0              70           6   0.6
# ...          ...       ...     ...             ...         ...   ...
# 12/31/2017     9      20.0       0              20           2  13.3
# 12/31/2017    12      20.0       0             250           3  13.8
# 12/31/2017    15      20.0       0              10           2   6.7
# 12/31/2017    18      15.0       0               0           0   4.0
# 12/31/2017    21      15.0       0              60           2   5.0
#
#             dew point    qfe     qff  rel_humid
# date
# 1/1/2013         -3.8  914.4  1031.6         97
# 1/1/2013         -6.3  915.7  1033.7         90
# 1/1/2013         -5.1  916.9  1034.8         83
# 1/1/2013         -5.4  915.7  1032.5         62
# 1/1/2013         -6.0  914.7  1031.9         61
# ...               ...    ...     ...        ...
# 12/31/2017       -6.8  909.4  1021.4         24
# 12/31/2017       -7.0  908.5  1020.5         23
# 12/31/2017       -7.8  909.0  1023.1         35
# 12/31/2017       -9.0  909.4  1023.0         38
# 12/31/2017       -8.9  909.1  1021.0         36
#
# [14608 rows x 10 columns]

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# hour              0
# دید افقی          0
# cloudy            0
# wind direction    0
# wind speed        0
# temp              0
# dew point         0
# qfe               0
# qff               0
# rel_humid         0
# dtype: int64

# %%
weather.dtypes
# Out:
# hour                int64
# دید افقی          float64
# cloudy              int64
# wind direction      int64
# wind speed          int64
# temp              float64
# dew point         float64
# qfe               float64
# qff               float64
# rel_humid           int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1/1/2013', '1/1/2013', '1/1/2013', '1/1/2013', '1/1/2013', '1/1/2013',
#        '1/1/2013', '1/1/2013', '1/2/2013', '1/2/2013',
#        ...
#        '12/30/2017', '12/30/2017', '12/31/2017', '12/31/2017', '12/31/2017',
#        '12/31/2017', '12/31/2017', '12/31/2017', '12/31/2017', '12/31/2017'],
#       dtype='object', name='date', length=14608)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-01', '2013-01-01', '2013-01-01',
#                '2013-01-01', '2013-01-01', '2013-01-01', '2013-01-01',
#                '2013-01-02', '2013-01-02',
#                ...
#                '2017-12-30', '2017-12-30', '2017-12-31', '2017-12-31',
#                '2017-12-31', '2017-12-31', '2017-12-31', '2017-12-31',
#                '2017-12-31', '2017-12-31'],
#               dtype='datetime64[ns]', name='date', length=14608, freq=None)

# %%
weather.index.year
# Out:
# Int64Index([2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013,
#             ...
#             2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017],
#            dtype='int64', name='date', length=14608)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# 2013    2947
# 2014    2901
# 2015    2915
# 2016    2927
# 2017    2918
# Name: date, dtype: int64

# %%
weather["temp"].plot()

# %%
#predict
weather["target"] = weather.shift(-1)['temp']

# %%
weather
# Out:
#             hour  دید افقی  cloudy  wind direction  wind speed  temp  \
# date
# 2013-01-01     0       5.0       5              80           2  -3.4
# 2013-01-01     3       8.0       1              90           3  -5.0
# 2013-01-01     6      25.0       0              90           7  -2.6
# 2013-01-01     9      25.0       0              70           3   1.0
# 2013-01-01    12      25.0       0              70           6   0.6
# ...          ...       ...     ...             ...         ...   ...
# 2017-12-31     9      20.0       0              20           2  13.3
# 2017-12-31    12      20.0       0             250           3  13.8
# 2017-12-31    15      20.0       0              10           2   6.7
# 2017-12-31    18      15.0       0               0           0   4.0
# 2017-12-31    21      15.0       0              60           2   5.0
#
#             dew point    qfe     qff  rel_humid  target
# date
# 2013-01-01       -3.8  914.4  1031.6         97    -5.0
# 2013-01-01       -6.3  915.7  1033.7         90    -2.6
# 2013-01-01       -5.1  916.9  1034.8         83     1.0
# 2013-01-01       -5.4  915.7  1032.5         62     0.6
# 2013-01-01       -6.0  914.7  1031.9         61    -2.4
# ...               ...    ...     ...        ...     ...
# 2017-12-31       -6.8  909.4  1021.4         24    13.8
# 2017-12-31       -7.0  908.5  1020.5         23     6.7
# 2017-12-31       -7.8  909.0  1023.1         35     4.0
# 2017-12-31       -9.0  909.4  1023.0         38     5.0
# 2017-12-31       -8.9  909.1  1021.0         36     NaN
#
# [14608 rows x 11 columns]

# %%
weather = weather.ffill()

# %%
weather
# Out:
#             hour  دید افقی  cloudy  wind direction  wind speed  temp  \
# date
# 2013-01-01     0       5.0       5              80           2  -3.4
# 2013-01-01     3       8.0       1              90           3  -5.0
# 2013-01-01     6      25.0       0              90           7  -2.6
# 2013-01-01     9      25.0       0              70           3   1.0
# 2013-01-01    12      25.0       0              70           6   0.6
# ...          ...       ...     ...             ...         ...   ...
# 2017-12-31     9      20.0       0              20           2  13.3
# 2017-12-31    12      20.0       0             250           3  13.8
# 2017-12-31    15      20.0       0              10           2   6.7
# 2017-12-31    18      15.0       0               0           0   4.0
# 2017-12-31    21      15.0       0              60           2   5.0
#
#             dew point    qfe     qff  rel_humid  target
# date
# 2013-01-01       -3.8  914.4  1031.6         97    -5.0
# 2013-01-01       -6.3  915.7  1033.7         90    -2.6
# 2013-01-01       -5.1  916.9  1034.8         83     1.0
# 2013-01-01       -5.4  915.7  1032.5         62     0.6
# 2013-01-01       -6.0  914.7  1031.9         61    -2.4
# ...               ...    ...     ...        ...     ...
# 2017-12-31       -6.8  909.4  1021.4         24    13.8
# 2017-12-31       -7.0  908.5  1020.5         23     6.7
# 2017-12-31       -7.8  909.0  1023.1         35     4.0
# 2017-12-31       -9.0  909.4  1023.0         38     5.0
# 2017-12-31       -8.9  909.1  1021.0         36     5.0
#
# [14608 rows x 11 columns]

# %%
from sklearn.linear_model import Ridge

# %%
weather.corr()
# Out:
#                     hour  دید افقی    cloudy  wind direction  wind speed  \
# hour            1.000000  0.000091 -0.001062        0.047564    0.003974
# دید افقی        0.000091  1.000000  0.106124        0.031194    0.023052
# cloudy         -0.001062  0.106124  1.000000        0.141775   -0.053091
# wind direction  0.047564  0.031194  0.141775        1.000000    0.232084
# wind speed      0.003974  0.023052 -0.053091        0.232084    1.000000
# temp            0.080429 -0.039932 -0.191992        0.096536    0.251402
# dew point      -0.047744  0.053831  0.181463        0.028648    0.140460
# qfe            -0.053915 -0.006513 -0.027496       -0.107434   -0.197007
# qff            -0.036857  0.011253  0.090259       -0.074176   -0.257285
# rel_humid      -0.107274  0.114810  0.323095       -0.076845   -0.183488
# target         -0.099888 -0.040085 -0.215204        0.047904    0.253331
#
#                     temp  dew point       qfe       qff  rel_humid    target
# hour            0.080429  -0.047744 -0.053915 -0.036857  -0.107274 -0.099888
# دید افقی       -0.039932   0.053831 -0.006513  0.011253   0.114810 -0.040085
# cloudy         -0.191992   0.181463 -0.027496  0.090259   0.323095 -0.215204
# wind direction  0.096536   0.028648 -0.107434 -0.074176  -0.076845  0.047904
# wind speed      0.251402   0.140460 -0.197007 -0.257285  -0.183488  0.253331
# temp            1.000000   0.291303 -0.688525 -0.851213  -0.772897  0.950109
# dew point       0.291303   1.000000 -0.338408 -0.398038   0.274419  0.320686
# qfe            -0.688525  -0.338408  1.000000  0.949139   0.417424 -0.644758
# qff            -0.851213  -0.398038  0.949139  1.000000   0.558091 -0.817721
# rel_humid      -0.772897   0.274419  0.417424  0.558091   1.000000 -0.715241
# target          0.950109   0.320686 -0.644758 -0.817721  -0.715241  1.000000

# %%
#apply ml

rr = Ridge(alpha=.1)

# %%
#apply Rodge regression

predictors = weather.columns[~weather.columns.isin(['target', 'date', 'hour', 'دید افقی'])]

# %%
predictors
# Out:
# Index(['cloudy', 'wind direction', 'wind speed', 'temp', 'dew point', 'qfe',
#        'qff', 'rel_humid'],
#       dtype='object')

# %%
#account for
def backtest(weather, model, predictors, start=1, step=90):
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        
        preds  = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        
        combined.columns = ['actual', 'prediction']
        
        combined["diff"] = (combined["prediction"]-combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
predictions
# Out:
#             actual  prediction      diff
# date
# 2013-01-01    -2.6   -5.000000  2.400000
# 2013-01-01     1.0   -5.000000  6.000000
# 2013-01-01     0.6   -5.000000  5.600000
# 2013-01-01    -2.4   -5.000000  2.600000
# 2013-01-01    -3.6   -5.000000  1.400000
# ...            ...         ...       ...
# 2017-12-31    13.8   12.570614  1.229386
# 2017-12-31     6.7   12.207491  5.507491
# 2017-12-31     4.0    6.157191  2.157191
# 2017-12-31     5.0    4.419292  0.580708
# 2017-12-31     5.0    6.079214  1.079214
#
# [14607 rows x 3 columns]

# %%
#how effective/ accurate
from sklearn.metrics import mean_absolute_error


mean_absolute_error(predictions['actual'], predictions['prediction'])
# Out:
# 2.783425797114869

# %%
predictions['diff'].mean()
# Out:
# 2.7834257971148655

# %%
#improve accuracy
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}-{col}"
    
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}-pct"] = pct_diff(weather[label], weather[col])
    return weather

rolling_horizons = [3, 14]

for horizon in rolling_horizons:
    for col in["temp", "rel_humid", "wind speed"]:
        weather = compute_rolling(weather, horizon, col)

# %%
weather
# Out:
#             hour  دید افقی  cloudy  wind direction  wind speed  temp  \
# date
# 2013-01-01     0       5.0       5              80           2  -3.4
# 2013-01-01     3       8.0       1              90           3  -5.0
# 2013-01-01     6      25.0       0              90           7  -2.6
# 2013-01-01     9      25.0       0              70           3   1.0
# 2013-01-01    12      25.0       0              70           6   0.6
# ...          ...       ...     ...             ...         ...   ...
# 2017-12-31     9      20.0       0              20           2  13.3
# 2017-12-31    12      20.0       0             250           3  13.8
# 2017-12-31    15      20.0       0              10           2   6.7
# 2017-12-31    18      15.0       0               0           0   4.0
# 2017-12-31    21      15.0       0              60           2   5.0
#
#             dew point    qfe     qff  rel_humid  ...  rolling_3-rel_humid  \
# date                                             ...
# 2013-01-01       -3.8  914.4  1031.6         97  ...                  NaN
# 2013-01-01       -6.3  915.7  1033.7         90  ...                  NaN
# 2013-01-01       -5.1  916.9  1034.8         83  ...            90.000000
# 2013-01-01       -5.4  915.7  1032.5         62  ...            78.333333
# 2013-01-01       -6.0  914.7  1031.9         61  ...            68.666667
# ...               ...    ...     ...        ...  ...                  ...
# 2017-12-31       -6.8  909.4  1021.4         24  ...            31.666667
# 2017-12-31       -7.0  908.5  1020.5         23  ...            25.666667
# 2017-12-31       -7.8  909.0  1023.1         35  ...            27.333333
# 2017-12-31       -9.0  909.4  1023.0         38  ...            32.000000
# 2017-12-31       -8.9  909.1  1021.0         36  ...            36.333333
#
#             rolling_3-rel_humid-pct  rolling_3-wind speed  \
# date
# 2013-01-01                      NaN                   NaN
# 2013-01-01                      NaN                   NaN
# 2013-01-01                -0.077778              4.000000
# 2013-01-01                -0.208511              4.333333
# 2013-01-01                -0.111650              5.333333
# ...                             ...                   ...
# 2017-12-31                -0.242105              3.000000
# 2017-12-31                -0.103896              2.666667
# 2017-12-31                 0.280488              2.333333
# 2017-12-31                 0.187500              1.666667
# 2017-12-31                -0.009174              1.333333
#
#             rolling_3-wind speed-pct  rolling_14-temp  rolling_14-temp-pct  \
# date
# 2013-01-01                       NaN              NaN                  NaN
# 2013-01-01                       NaN              NaN                  NaN
# 2013-01-01                  0.750000              NaN                  NaN
# 2013-01-01                 -0.307692              NaN                  NaN
# 2013-01-01                  0.125000              NaN                  NaN
# ...                              ...              ...                  ...
# 2017-12-31                 -0.333333         5.964286             1.229940
# 2017-12-31                  0.125000         6.521429             1.116101
# 2017-12-31                 -0.142857         6.757143            -0.008457
# 2017-12-31                 -1.000000         6.864286            -0.417274
# 2017-12-31                  0.500000         7.207143            -0.306244
#
#             rolling_14-rel_humid  rolling_14-rel_humid-pct  \
# date
# 2013-01-01                   NaN                       NaN
# 2013-01-01                   NaN                       NaN
# 2013-01-01                   NaN                       NaN
# 2013-01-01                   NaN                       NaN
# 2013-01-01                   NaN                       NaN
# ...                          ...                       ...
# 2017-12-31             34.214286                 -0.298539
# 2017-12-31             33.285714                 -0.309013
# 2017-12-31             33.071429                  0.058315
# 2017-12-31             33.142857                  0.146552
# 2017-12-31             32.571429                  0.105263
#
#             rolling_14-wind speed  rolling_14-wind speed-pct
# date
# 2013-01-01                    NaN                        NaN
# 2013-01-01                    NaN                        NaN
# 2013-01-01                    NaN                        NaN
# 2013-01-01                    NaN                        NaN
# 2013-01-01                    NaN                        NaN
# ...                           ...                        ...
# 2017-12-31               1.500000                   0.333333
# 2017-12-31               1.571429                   0.909091
# 2017-12-31               1.714286                   0.166667
# 2017-12-31               1.571429                  -1.000000
# 2017-12-31               1.714286                   0.166667
#
# [14608 rows x 23 columns]

# %%
weather = weather.iloc[14:,:]

# %%
weather
# Out:
#             hour  دید افقی  cloudy  wind direction  wind speed  temp  \
# date
# 2013-01-04    12      15.0       1             100           4   2.8
# 2013-01-04    15      15.0       0              70           4  -0.6
# 2013-01-04    18      15.0       0              70           5  -1.0
# 2013-01-04    21      15.0       0              60           4  -3.0
# 2013-01-05     0      15.0       0              70           5  -3.6
# ...          ...       ...     ...             ...         ...   ...
# 2017-12-31     9      20.0       0              20           2  13.3
# 2017-12-31    12      20.0       0             250           3  13.8
# 2017-12-31    15      20.0       0              10           2   6.7
# 2017-12-31    18      15.0       0               0           0   4.0
# 2017-12-31    21      15.0       0              60           2   5.0
#
#             dew point    qfe     qff  rel_humid  ...  rolling_3-rel_humid  \
# date                                             ...
# 2013-01-04       -4.8  910.6  1026.8         57  ...            58.666667
# 2013-01-04       -7.0  910.7  1028.0         62  ...            57.666667
# 2013-01-04       -6.9  910.5  1026.9         64  ...            61.000000
# 2013-01-04       -7.4  909.6  1025.5         72  ...            66.000000
# 2013-01-05       -8.2  908.2  1024.1         70  ...            68.666667
# ...               ...    ...     ...        ...  ...                  ...
# 2017-12-31       -6.8  909.4  1021.4         24  ...            31.666667
# 2017-12-31       -7.0  908.5  1020.5         23  ...            25.666667
# 2017-12-31       -7.8  909.0  1023.1         35  ...            27.333333
# 2017-12-31       -9.0  909.4  1023.0         38  ...            32.000000
# 2017-12-31       -8.9  909.1  1021.0         36  ...            36.333333
#
#             rolling_3-rel_humid-pct  rolling_3-wind speed  \
# date
# 2013-01-04                -0.028409              4.666667
# 2013-01-04                 0.075145              4.000000
# 2013-01-04                 0.049180              4.333333
# 2013-01-04                 0.090909              4.333333
# 2013-01-05                 0.019417              4.666667
# ...                             ...                   ...
# 2017-12-31                -0.242105              3.000000
# 2017-12-31                -0.103896              2.666667
# 2017-12-31                 0.280488              2.333333
# 2017-12-31                 0.187500              1.666667
# 2017-12-31                -0.009174              1.333333
#
#             rolling_3-wind speed-pct  rolling_14-temp  rolling_14-temp-pct  \
# date
# 2013-01-04                 -0.142857        -1.314286            -3.130435
# 2013-01-04                  0.000000        -1.085714            -0.447368
# 2013-01-04                  0.153846        -0.757143             0.320755
# 2013-01-04                 -0.076923        -0.642857             3.666667
# 2013-01-05                  0.071429        -0.771429             3.666667
# ...                              ...              ...                  ...
# 2017-12-31                 -0.333333         5.964286             1.229940
# 2017-12-31                  0.125000         6.521429             1.116101
# 2017-12-31                 -0.142857         6.757143            -0.008457
# 2017-12-31                 -1.000000         6.864286            -0.417274
# 2017-12-31                  0.500000         7.207143            -0.306244
#
#             rolling_14-rel_humid  rolling_14-rel_humid-pct  \
# date
# 2013-01-04             62.428571                 -0.086957
# 2013-01-04             62.785714                 -0.012514
# 2013-01-04             62.642857                  0.021665
# 2013-01-04             63.214286                  0.138983
# 2013-01-05             64.571429                  0.084071
# ...                          ...                       ...
# 2017-12-31             34.214286                 -0.298539
# 2017-12-31             33.285714                 -0.309013
# 2017-12-31             33.071429                  0.058315
# 2017-12-31             33.142857                  0.146552
# 2017-12-31             32.571429                  0.105263
#
#             rolling_14-wind speed  rolling_14-wind speed-pct
# date
# 2013-01-04               4.214286                  -0.050847
# 2013-01-04               4.285714                  -0.066667
# 2013-01-04               4.428571                   0.129032
# 2013-01-04               4.428571                  -0.096774
# 2013-01-05               4.428571                   0.129032
# ...                           ...                        ...
# 2017-12-31               1.500000                   0.333333
# 2017-12-31               1.571429                   0.909091
# 2017-12-31               1.714286                   0.166667
# 2017-12-31               1.571429                  -1.000000
# 2017-12-31               1.714286                   0.166667
#
# [14580 rows x 23 columns]

# %%
weather = weather.fillna(0)

# %%
weather[weather.index.duplicated()]
# Out:
#             hour  دید افقی  cloudy  wind direction  wind speed  temp  \
# date
# 2013-01-04    15      15.0       0              70           4  -0.6
# 2013-01-04    18      15.0       0              70           5  -1.0
# 2013-01-04    21      15.0       0              60           4  -3.0
# 2013-01-05     3      15.0       0              70           3  -3.2
# 2013-01-05     6      15.0       5              80           6  -1.2
# ...          ...       ...     ...             ...         ...   ...
# 2017-12-31     9      20.0       0              20           2  13.3
# 2017-12-31    12      20.0       0             250           3  13.8
# 2017-12-31    15      20.0       0              10           2   6.7
# 2017-12-31    18      15.0       0               0           0   4.0
# 2017-12-31    21      15.0       0              60           2   5.0
#
#             dew point    qfe     qff  rel_humid  ...  rolling_3-rel_humid  \
# date                                             ...
# 2013-01-04       -7.0  910.7  1028.0         62  ...            57.666667
# 2013-01-04       -6.9  910.5  1026.9         64  ...            61.000000
# 2013-01-04       -7.4  909.6  1025.5         72  ...            66.000000
# 2013-01-05       -7.6  907.3  1023.7         71  ...            71.000000
# 2013-01-05       -7.1  906.7  1022.7         64  ...            68.333333
# ...               ...    ...     ...        ...  ...                  ...
# 2017-12-31       -6.8  909.4  1021.4         24  ...            31.666667
# 2017-12-31       -7.0  908.5  1020.5         23  ...            25.666667
# 2017-12-31       -7.8  909.0  1023.1         35  ...            27.333333
# 2017-12-31       -9.0  909.4  1023.0         38  ...            32.000000
# 2017-12-31       -8.9  909.1  1021.0         36  ...            36.333333
#
#             rolling_3-rel_humid-pct  rolling_3-wind speed  \
# date
# 2013-01-04                 0.075145              4.000000
# 2013-01-04                 0.049180              4.333333
# 2013-01-04                 0.090909              4.333333
# 2013-01-05                 0.000000              4.000000
# 2013-01-05                -0.063415              4.666667
# ...                             ...                   ...
# 2017-12-31                -0.242105              3.000000
# 2017-12-31                -0.103896              2.666667
# 2017-12-31                 0.280488              2.333333
# 2017-12-31                 0.187500              1.666667
# 2017-12-31                -0.009174              1.333333
#
#             rolling_3-wind speed-pct  rolling_14-temp  rolling_14-temp-pct  \
# date
# 2013-01-04                  0.000000        -1.085714            -0.447368
# 2013-01-04                  0.153846        -0.757143             0.320755
# 2013-01-04                 -0.076923        -0.642857             3.666667
# 2013-01-05                 -0.250000        -1.285714             1.488889
# 2013-01-05                  0.285714        -1.657143            -0.275862
# ...                              ...              ...                  ...
# 2017-12-31                 -0.333333         5.964286             1.229940
# 2017-12-31                  0.125000         6.521429             1.116101
# 2017-12-31                 -0.142857         6.757143            -0.008457
# 2017-12-31                 -1.000000         6.864286            -0.417274
# 2017-12-31                  0.500000         7.207143            -0.306244
#
#             rolling_14-rel_humid  rolling_14-rel_humid-pct  \
# date
# 2013-01-04             62.785714                 -0.012514
# 2013-01-04             62.642857                  0.021665
# 2013-01-04             63.214286                  0.138983
# 2013-01-05             66.428571                  0.068817
# 2013-01-05             67.357143                 -0.049841
# ...                          ...                       ...
# 2017-12-31             34.214286                 -0.298539
# 2017-12-31             33.285714                 -0.309013
# 2017-12-31             33.071429                  0.058315
# 2017-12-31             33.142857                  0.146552
# 2017-12-31             32.571429                  0.105263
#
#             rolling_14-wind speed  rolling_14-wind speed-pct
# date
# 2013-01-04               4.285714                  -0.066667
# 2013-01-04               4.428571                   0.129032
# 2013-01-04               4.428571                  -0.096774
# 2013-01-05               4.428571                  -0.322581
# 2013-01-05               4.571429                   0.312500
# ...                           ...                        ...
# 2017-12-31               1.500000                   0.333333
# 2017-12-31               1.571429                   0.909091
# 2017-12-31               1.714286                   0.166667
# 2017-12-31               1.571429                  -1.000000
# 2017-12-31               1.714286                   0.166667
#
# [12758 rows x 23 columns]

# %%
weather = weather[~weather.index.duplicated()]

# %%
def expand_mean(df):
    return df.expanding(1).mean()

#add columns
for col in["temp", "rel_humid", "wind speed"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day, group_keys=False).apply(expand_mean)
# Out:
# C:\Users\Vahid\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Vahid\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
weather
# Out:
#             hour  دید افقی  cloudy  wind direction  wind speed  temp  \
# date
# 2013-01-04    12      15.0       1             100           4   2.8
# 2013-01-05     0      15.0       0              70           5  -3.6
# 2013-01-06     0      15.0       0               0           0  -1.4
# 2013-01-07     0      15.0       0              60           4   0.6
# 2013-01-08     0      15.0       0              40           2   2.4
# ...          ...       ...     ...             ...         ...   ...
# 2017-12-27     0      20.0       0               0           0   2.1
# 2017-12-28     0      15.0       0              60           2   1.5
# 2017-12-29     0      15.0       0              60           3   1.3
# 2017-12-30     0      20.0       0              60           2   2.5
# 2017-12-31     0      15.0       0              60           2   3.3
#
#             dew point    qfe     qff  rel_humid  ...  rolling_14-rel_humid  \
# date                                             ...
# 2013-01-04       -4.8  910.6  1026.8         57  ...             62.428571
# 2013-01-05       -8.2  908.2  1024.1         70  ...             64.571429
# 2013-01-06       -6.6  902.0  1016.0         67  ...             61.214286
# 2013-01-07       -4.6  903.9  1017.1         68  ...             58.642857
# 2013-01-08       -1.9  900.6  1012.7         73  ...             58.142857
# ...               ...    ...     ...        ...  ...                   ...
# 2017-12-27       -4.6  919.8  1033.9         61  ...             44.000000
# 2017-12-28       -7.3  917.9  1031.8         52  ...             42.500000
# 2017-12-29      -15.5  914.3  1027.8         27  ...             33.857143
# 2017-12-30      -10.8  911.7  1024.6         37  ...             29.357143
# 2017-12-31       -9.2  910.2  1022.4         39  ...             32.428571
#
#             rolling_14-rel_humid-pct  rolling_14-wind speed  \
# date
# 2013-01-04                 -0.086957               4.214286
# 2013-01-05                  0.084071               4.428571
# 2013-01-06                  0.094516               3.714286
# 2013-01-07                  0.159562               2.642857
# 2013-01-08                  0.255528               3.214286
# ...                              ...                    ...
# 2017-12-27                  0.386364               3.785714
# 2017-12-28                  0.223529               4.357143
# 2017-12-29                 -0.202532               2.714286
# 2017-12-30                  0.260341               1.714286
# 2017-12-31                  0.202643               1.142857
#
#             rolling_14-wind speed-pct  month_avg_temp  day_avg_temp  \
# date
# 2013-01-04                  -0.050847        2.800000      2.800000
# 2013-01-05                   0.129032       -0.400000     -3.600000
# 2013-01-06                  -1.000000       -0.733333     -1.400000
# 2013-01-07                   0.513514       -0.400000      0.600000
# 2013-01-08                  -0.377778        0.160000      2.400000
# ...                               ...             ...           ...
# 2017-12-27                  -1.000000        3.194702     13.956667
# 2017-12-28                  -0.540984        3.183553     13.801695
# 2017-12-29                   0.105263        3.171242     15.632143
# 2017-12-30                   0.166667        3.166883     15.140000
# 2017-12-31                   0.750000        3.167742     14.331429
#
#             month_avg_rel_humid  day_avg_rel_humid  month_avg_wind speed  \
# date
# 2013-01-04            57.000000          57.000000              4.000000
# 2013-01-05            63.500000          70.000000              4.500000
# 2013-01-06            64.666667          67.000000              3.000000
# 2013-01-07            65.500000          68.000000              3.250000
# 2013-01-08            67.000000          73.000000              3.000000
# ...                         ...                ...                   ...
# 2017-12-27            60.119205          43.150000              2.834437
# 2017-12-28            60.065789          45.000000              2.828947
# 2017-12-29            59.849673          41.000000              2.830065
# 2017-12-30            59.701299          40.327273              2.824675
# 2017-12-31            59.567742          42.600000              2.819355
#
#             day_avg_wind speed
# date
# 2013-01-04            4.000000
# 2013-01-05            5.000000
# 2013-01-06            0.000000
# 2013-01-07            4.000000
# 2013-01-08            2.000000
# ...                        ...
# 2017-12-27            3.950000
# 2017-12-28            3.813559
# 2017-12-29            4.053571
# 2017-12-30            3.763636
# 2017-12-31            3.371429
#
# [1822 rows x 29 columns]

# %%
predictors=weather.columns[~weather.columns.isin(['target', 'date', 'hour', 'دید افقی'])]

# %%
predictors
# Out:
# Index(['cloudy', 'wind direction', 'wind speed', 'temp', 'dew point', 'qfe',
#        'qff', 'rel_humid', 'rolling_3-temp', 'rolling_3-temp-pct',
#        'rolling_3-rel_humid', 'rolling_3-rel_humid-pct',
#        'rolling_3-wind speed', 'rolling_3-wind speed-pct', 'rolling_14-temp',
#        'rolling_14-temp-pct', 'rolling_14-rel_humid',
#        'rolling_14-rel_humid-pct', 'rolling_14-wind speed',
#        'rolling_14-wind speed-pct', 'month_avg_temp', 'day_avg_temp',
#        'month_avg_rel_humid', 'day_avg_rel_humid', 'month_avg_wind speed',
#        'day_avg_wind speed'],
#       dtype='object')

# %%
predictions = backtest(weather, rr, predictors)

# %%
mean_absolute_error(predictions['actual'], predictions['prediction'])
# Out:
# 1.4199541401493552

# %%
predictions.sort_values('diff', ascending=False)
# Out:
#             actual  prediction       diff
# date
# 2013-03-06    20.7   -0.600000  21.300000
# 2013-03-25    13.8   -0.600000  14.400000
# 2013-03-18    13.6   -0.600000  14.200000
# 2013-03-05    13.3   -0.600000  13.900000
# 2016-11-24    -3.1   10.750930  13.850930
# ...            ...         ...        ...
# 2015-05-01    18.3   18.294068   0.005932
# 2017-03-21    12.7   12.696303   0.003697
# 2016-11-22     1.6    1.597197   0.002803
# 2014-12-01     4.1    4.102546   0.002546
# 2013-01-15    -0.6   -0.600000   0.000000
#
# [1821 rows x 3 columns]

# %%
weather.loc["2013-01-1":"2017-12-31"]
# Out:
# C:\Users\Vahid\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   """Entry point for launching an IPython kernel.
#             hour  دید افقی  cloudy  wind direction  wind speed  temp  \
# date
# 2013-01-04    12      15.0       1             100           4   2.8
# 2013-01-05     0      15.0       0              70           5  -3.6
# 2013-01-06     0      15.0       0               0           0  -1.4
# 2013-01-07     0      15.0       0              60           4   0.6
# 2013-01-08     0      15.0       0              40           2   2.4
# ...          ...       ...     ...             ...         ...   ...
# 2017-12-27     0      20.0       0               0           0   2.1
# 2017-12-28     0      15.0       0              60           2   1.5
# 2017-12-29     0      15.0       0              60           3   1.3
# 2017-12-30     0      20.0       0              60           2   2.5
# 2017-12-31     0      15.0       0              60           2   3.3
#
#             dew point    qfe     qff  rel_humid  ...  rolling_14-rel_humid  \
# date                                             ...
# 2013-01-04       -4.8  910.6  1026.8         57  ...             62.428571
# 2013-01-05       -8.2  908.2  1024.1         70  ...             64.571429
# 2013-01-06       -6.6  902.0  1016.0         67  ...             61.214286
# 2013-01-07       -4.6  903.9  1017.1         68  ...             58.642857
# 2013-01-08       -1.9  900.6  1012.7         73  ...             58.142857
# ...               ...    ...     ...        ...  ...                   ...
# 2017-12-27       -4.6  919.8  1033.9         61  ...             44.000000
# 2017-12-28       -7.3  917.9  1031.8         52  ...             42.500000
# 2017-12-29      -15.5  914.3  1027.8         27  ...             33.857143
# 2017-12-30      -10.8  911.7  1024.6         37  ...             29.357143
# 2017-12-31       -9.2  910.2  1022.4         39  ...             32.428571
#
#             rolling_14-rel_humid-pct  rolling_14-wind speed  \
# date
# 2013-01-04                 -0.086957               4.214286
# 2013-01-05                  0.084071               4.428571
# 2013-01-06                  0.094516               3.714286
# 2013-01-07                  0.159562               2.642857
# 2013-01-08                  0.255528               3.214286
# ...                              ...                    ...
# 2017-12-27                  0.386364               3.785714
# 2017-12-28                  0.223529               4.357143
# 2017-12-29                 -0.202532               2.714286
# 2017-12-30                  0.260341               1.714286
# 2017-12-31                  0.202643               1.142857
#
#             rolling_14-wind speed-pct  month_avg_temp  day_avg_temp  \
# date
# 2013-01-04                  -0.050847        2.800000      2.800000
# 2013-01-05                   0.129032       -0.400000     -3.600000
# 2013-01-06                  -1.000000       -0.733333     -1.400000
# 2013-01-07                   0.513514       -0.400000      0.600000
# 2013-01-08                  -0.377778        0.160000      2.400000
# ...                               ...             ...           ...
# 2017-12-27                  -1.000000        3.194702     13.956667
# 2017-12-28                  -0.540984        3.183553     13.801695
# 2017-12-29                   0.105263        3.171242     15.632143
# 2017-12-30                   0.166667        3.166883     15.140000
# 2017-12-31                   0.750000        3.167742     14.331429
#
#             month_avg_rel_humid  day_avg_rel_humid  month_avg_wind speed  \
# date
# 2013-01-04            57.000000          57.000000              4.000000
# 2013-01-05            63.500000          70.000000              4.500000
# 2013-01-06            64.666667          67.000000              3.000000
# 2013-01-07            65.500000          68.000000              3.250000
# 2013-01-08            67.000000          73.000000              3.000000
# ...                         ...                ...                   ...
# 2017-12-27            60.119205          43.150000              2.834437
# 2017-12-28            60.065789          45.000000              2.828947
# 2017-12-29            59.849673          41.000000              2.830065
# 2017-12-30            59.701299          40.327273              2.824675
# 2017-12-31            59.567742          42.600000              2.819355
#
#             day_avg_wind speed
# date
# 2013-01-04            4.000000
# 2013-01-05            5.000000
# 2013-01-06            0.000000
# 2013-01-07            4.000000
# 2013-01-08            2.000000
# ...                        ...
# 2017-12-27            3.950000
# 2017-12-28            3.813559
# 2017-12-29            4.053571
# 2017-12-30            3.763636
# 2017-12-31            3.371429
#
# [1822 rows x 29 columns]

# %%
predictions['diff'].round().value_counts()
# Out:
# 1.0     754
# 0.0     537
# 2.0     289
# 3.0     102
# 4.0      40
# 5.0      30
# 6.0      21
# 8.0      11
# 11.0     10
# 7.0       8
# 10.0      6
# 14.0      6
# 9.0       4
# 21.0      1
# 12.0      1
# 13.0      1
# Name: diff, dtype: int64

# %%
predictions['diff'].round().value_counts().sort_index()
# Out:
# 0.0     537
# 1.0     754
# 2.0     289
# 3.0     102
# 4.0      40
# 5.0      30
# 6.0      21
# 7.0       8
# 8.0      11
# 9.0       4
# 10.0      6
# 11.0     10
# 12.0      1
# 13.0      1
# 14.0      6
# 21.0      1
# Name: diff, dtype: int64

# %%
predictions['diff'].round().value_counts().plot()
