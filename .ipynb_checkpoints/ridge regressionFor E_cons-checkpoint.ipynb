# %%
import pandas as pd
weather = pd.read_csv("D:\\paper\\C\\data\\5\\realityvalues.csv", index_col="date")

# %%
weather
# Out:
#            En_Requests (MJ)  co2_emission (kg)  Temperature  rel_humidity  \
# date
# 1/1/2013      117956.148100        6706.050347     4.722581     53.850806
# 2/1/2013       96721.295220        5529.880088     8.969643     53.705357
# 3/1/2013       63957.882600        3631.034783    13.286694     48.274194
# 4/1/2013       26955.591150        1775.929938    17.629167     35.912500
# 5/1/2013        9313.743056        1007.498740    23.872177     26.903226
# ...                     ...                ...          ...           ...
# 8/1/2021       17710.979310        2632.185978    30.116129     16.032258
# 9/1/2021       15581.750790        2050.973382    28.017083     19.737500
# 10/1/2021      29245.577180        2257.935407    16.740726     26.112903
# 11/1/2021      65196.930390        3890.085236    10.424167     42.420833
# 12/1/2021      79314.280940        4675.045226     7.497581     41.411290
#
#            solar_hour  Wind_Speed
# date
# ...

# %%
null_pct=weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
weather.apply(pd.isnull).sum()
# Out:
# En_Requests (MJ)     0
# co2_emission (kg)    0
# Temperature          0
# rel_humidity         0
# solar_hour           0
# Wind_Speed           0
# dtype: int64

# %%
null_pct
# Out:
# En_Requests (MJ)     0.0
# co2_emission (kg)    0.0
# Temperature          0.0
# rel_humidity         0.0
# solar_hour           0.0
# Wind_Speed           0.0
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < .05]

# %%
valid_columns
# Out:
# Index(['En_Requests (MJ)', 'co2_emission (kg)', 'Temperature', 'rel_humidity',
#        'solar_hour', 'Wind_Speed'],
#       dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#            en_requests (mj)  co2_emission (kg)  temperature  rel_humidity  \
# date
# 1/1/2013      117956.148100        6706.050347     4.722581     53.850806
# 2/1/2013       96721.295220        5529.880088     8.969643     53.705357
# 3/1/2013       63957.882600        3631.034783    13.286694     48.274194
# 4/1/2013       26955.591150        1775.929938    17.629167     35.912500
# 5/1/2013        9313.743056        1007.498740    23.872177     26.903226
# ...                     ...                ...          ...           ...
# 8/1/2021       17710.979310        2632.185978    30.116129     16.032258
# 9/1/2021       15581.750790        2050.973382    28.017083     19.737500
# 10/1/2021      29245.577180        2257.935407    16.740726     26.112903
# 11/1/2021      65196.930390        3890.085236    10.424167     42.420833
# 12/1/2021      79314.280940        4675.045226     7.497581     41.411290
#
#            solar_hour  wind_speed
# date
# ...

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# en_requests (mj)     0
# co2_emission (kg)    0
# temperature          0
# rel_humidity         0
# solar_hour           0
# wind_speed           0
# dtype: int64

# %%
weather.dtypes
# Out:
# en_requests (mj)     float64
# co2_emission (kg)    float64
# temperature          float64
# rel_humidity         float64
# solar_hour           float64
# wind_speed           float64
# dtype: object

# %%
weather.index
# Out:
# Index(['1/1/2013', '2/1/2013', '3/1/2013', '4/1/2013', '5/1/2013', '6/1/2013',
#        '7/1/2013', '8/1/2013', '9/1/2013', '10/1/2013',
#        ...
#        '3/1/2021', '4/1/2021', '5/1/2021', '6/1/2021', '7/1/2021', '8/1/2021',
#        '9/1/2021', '10/1/2021', '11/1/2021', '12/1/2021'],
#       dtype='object', name='date', length=108)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-02-01', '2013-03-01', '2013-04-01',
#                '2013-05-01', '2013-06-01', '2013-07-01', '2013-08-01',
#                '2013-09-01', '2013-10-01',
#                ...
#                '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01',
#                '2021-07-01', '2021-08-01', '2021-09-01', '2021-10-01',
#                '2021-11-01', '2021-12-01'],
#               dtype='datetime64[ns]', name='date', length=108, freq=None)

# %%
weather.index.date
# Out:
# array([datetime.date(2013, 1, 1), datetime.date(2013, 2, 1),
#        datetime.date(2013, 3, 1), datetime.date(2013, 4, 1),
#        datetime.date(2013, 5, 1), datetime.date(2013, 6, 1),
#        datetime.date(2013, 7, 1), datetime.date(2013, 8, 1),
#        datetime.date(2013, 9, 1), datetime.date(2013, 10, 1),
#        datetime.date(2013, 11, 1), datetime.date(2013, 12, 1),
#        datetime.date(2014, 1, 1), datetime.date(2014, 2, 1),
#        datetime.date(2014, 3, 1), datetime.date(2014, 4, 1),
#        datetime.date(2014, 5, 1), datetime.date(2014, 6, 1),
#        datetime.date(2014, 7, 1), datetime.date(2014, 8, 1),
#        datetime.date(2014, 9, 1), datetime.date(2014, 10, 1),
#        datetime.date(2014, 11, 1), datetime.date(2014, 12, 1),
#        datetime.date(2015, 1, 1), datetime.date(2015, 2, 1),
#        datetime.date(2015, 3, 1), datetime.date(2015, 4, 1),
#        datetime.date(2015, 5, 1), datetime.date(2015, 6, 1),
# ...

# %%
weather.index.year.value_counts().sort_index()
# Out:
# 2013    12
# 2014    12
# 2015    12
# 2016    12
# 2017    12
# 2018    12
# 2019    12
# 2020    12
# 2021    12
# Name: date, dtype: int64

# %%
weather["en_requests (mj)"].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#predict
weather["target"] = weather.shift(-1)['en_requests (mj)']

# %%
weather
# Out:
#             en_requests (mj)  co2_emission (kg)  temperature  rel_humidity  \
# date
# 2013-01-01     117956.148100        6706.050347     4.722581     53.850806
# 2013-02-01      96721.295220        5529.880088     8.969643     53.705357
# 2013-03-01      63957.882600        3631.034783    13.286694     48.274194
# 2013-04-01      26955.591150        1775.929938    17.629167     35.912500
# 2013-05-01       9313.743056        1007.498740    23.872177     26.903226
# ...                      ...                ...          ...           ...
# 2021-08-01      17710.979310        2632.185978    30.116129     16.032258
# 2021-09-01      15581.750790        2050.973382    28.017083     19.737500
# 2021-10-01      29245.577180        2257.935407    16.740726     26.112903
# 2021-11-01      65196.930390        3890.085236    10.424167     42.420833
# 2021-12-01      79314.280940        4675.045226     7.497581     41.411290
#
#             solar_hour  wind_speed        target
# date
# ...

# %%
weather = weather.ffill()

# %%
weather
# Out:
#             en_requests (mj)  co2_emission (kg)  temperature  rel_humidity  \
# date
# 2013-01-01     117956.148100        6706.050347     4.722581     53.850806
# 2013-02-01      96721.295220        5529.880088     8.969643     53.705357
# 2013-03-01      63957.882600        3631.034783    13.286694     48.274194
# 2013-04-01      26955.591150        1775.929938    17.629167     35.912500
# 2013-05-01       9313.743056        1007.498740    23.872177     26.903226
# ...                      ...                ...          ...           ...
# 2021-08-01      17710.979310        2632.185978    30.116129     16.032258
# 2021-09-01      15581.750790        2050.973382    28.017083     19.737500
# 2021-10-01      29245.577180        2257.935407    16.740726     26.112903
# 2021-11-01      65196.930390        3890.085236    10.424167     42.420833
# 2021-12-01      79314.280940        4675.045226     7.497581     41.411290
#
#             solar_hour  wind_speed        target
# date
# ...

# %%
from sklearn.linear_model import Ridge

# %%
weather.corr()
# Out:
#                    en_requests (mj)  co2_emission (kg)  temperature  \
# en_requests (mj)           1.000000           0.953949    -0.894357
# co2_emission (kg)          0.953949           1.000000    -0.764248
# temperature               -0.894357          -0.764248     1.000000
# rel_humidity               0.833817           0.707937    -0.890915
# solar_hour                -0.824953          -0.691029     0.932597
# wind_speed                -0.803651          -0.708928     0.871243
# target                     0.802678           0.755689    -0.802305
#
#                    rel_humidity  solar_hour  wind_speed    target
# en_requests (mj)       0.833817   -0.824953   -0.803651  0.802678
# co2_emission (kg)      0.707937   -0.691029   -0.708928  0.755689
# temperature           -0.890915    0.932597    0.871243 -0.802305
# rel_humidity           1.000000   -0.922799   -0.778258  0.671741
# solar_hour            -0.922799    1.000000    0.803760 -0.711438
# ...

# %%
#apply ml

rr = Ridge(alpha=.1)

# %%
#apply Rodge regression

predictors = weather.columns[~weather.columns.isin(['target', 'date'])]

# %%
predictors
# Out:
# Index(['en_requests (mj)', 'co2_emission (kg)', 'temperature', 'rel_humidity',
#        'solar_hour', 'wind_speed'],
#       dtype='object')

# %%
#account for
def backtest(weather, model, predictors, start=1, step=1):
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        
        preds  = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        
        combined.columns = ['actual', 'prediction']
        
        combined["diff"] = (combined["prediction"]-combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
predictions
# Out:
#                   actual     prediction          diff
# date
# 2013-02-01  63957.882600   96721.295220  32763.412620
# 2013-03-01  26955.591150   13399.906745  13555.684405
# 2013-04-01   9313.743056  -42751.488307  52065.231363
# 2013-05-01   9137.165036    4499.819960   4637.345076
# 2013-06-01   7840.302159   26695.599339  18855.297180
# ...                  ...            ...           ...
# 2021-08-01  15581.750790   35895.441253  20313.690463
# 2021-09-01  29245.577180   15208.931725  14036.645455
# 2021-10-01  65196.930390   60550.369209   4646.561181
# 2021-11-01  79314.280940   85366.658334   6052.377394
# 2021-12-01  79314.280940  111024.906145  31710.625205
#
# [107 rows x 3 columns]

# %%
#how effective/ accurate
from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions['actual'], predictions['prediction'])
# Out:
# 21234.298694981935

# %%
predictions['diff'].mean()
# Out:
# 21234.298694981935

# %%
#improve accuracy
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}-{col}"
    
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}-pct"] = pct_diff(weather[label], weather[col])
    return weather

rolling_horizons = [2, 2]

for horizon in rolling_horizons:
    for col in["en_requests (mj)", "co2_emission (kg)", "temperature", "rel_humidity", "solar_hour", "wind_speed"]:
        weather = compute_rolling(weather, horizon, col)

# %%
weather
# Out:
#             en_requests (mj)  co2_emission (kg)  temperature  rel_humidity  \
# date
# 2013-01-01     117956.148100        6706.050347     4.722581     53.850806
# 2013-02-01      96721.295220        5529.880088     8.969643     53.705357
# 2013-03-01      63957.882600        3631.034783    13.286694     48.274194
# 2013-04-01      26955.591150        1775.929938    17.629167     35.912500
# 2013-05-01       9313.743056        1007.498740    23.872177     26.903226
# ...                      ...                ...          ...           ...
# 2021-08-01      17710.979310        2632.185978    30.116129     16.032258
# 2021-09-01      15581.750790        2050.973382    28.017083     19.737500
# 2021-10-01      29245.577180        2257.935407    16.740726     26.112903
# 2021-11-01      65196.930390        3890.085236    10.424167     42.420833
# 2021-12-01      79314.280940        4675.045226     7.497581     41.411290
#
# ...

# %%
weather = weather.iloc[2:,:]

# %%
weather
# Out:
#             en_requests (mj)  co2_emission (kg)  temperature  rel_humidity  \
# date
# 2013-03-01      63957.882600        3631.034783    13.286694     48.274194
# 2013-04-01      26955.591150        1775.929938    17.629167     35.912500
# 2013-05-01       9313.743056        1007.498740    23.872177     26.903226
# 2013-06-01       9137.165036        1113.049043    30.010000     18.233333
# 2013-07-01       7840.302159        1037.774866    32.209274     19.032258
# ...                      ...                ...          ...           ...
# 2021-08-01      17710.979310        2632.185978    30.116129     16.032258
# 2021-09-01      15581.750790        2050.973382    28.017083     19.737500
# 2021-10-01      29245.577180        2257.935407    16.740726     26.112903
# 2021-11-01      65196.930390        3890.085236    10.424167     42.420833
# 2021-12-01      79314.280940        4675.045226     7.497581     41.411290
#
# ...

# %%
weather = weather.fillna(0)

# %%
weather[weather.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [en_requests (mj), co2_emission (kg), temperature, rel_humidity, solar_hour, wind_speed, target, rolling_2-en_requests (mj), rolling_2-en_requests (mj)-pct, rolling_2-co2_emission (kg), rolling_2-co2_emission (kg)-pct, rolling_2-temperature, rolling_2-temperature-pct, rolling_2-rel_humidity, rolling_2-rel_humidity-pct, rolling_2-solar_hour, rolling_2-solar_hour-pct, rolling_2-wind_speed, rolling_2-wind_speed-pct]
# Index: []

# %%
weather = weather[~weather.index.duplicated()]

# %%
def expand_mean(df):
    return df.expanding(1).mean()

#add columns
for col in["en_requests (mj)", "co2_emission (kg)", "temperature", "rel_humidity", "solar_hour", "wind_speed"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day, group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#             en_requests (mj)  co2_emission (kg)  temperature  rel_humidity  \
# date
# 2013-03-01      63957.882600        3631.034783    13.286694     48.274194
# 2013-04-01      26955.591150        1775.929938    17.629167     35.912500
# 2013-05-01       9313.743056        1007.498740    23.872177     26.903226
# 2013-06-01       9137.165036        1113.049043    30.010000     18.233333
# 2013-07-01       7840.302159        1037.774866    32.209274     19.032258
# ...                      ...                ...          ...           ...
# 2021-08-01      17710.979310        2632.185978    30.116129     16.032258
# 2021-09-01      15581.750790        2050.973382    28.017083     19.737500
# 2021-10-01      29245.577180        2257.935407    16.740726     26.112903
# 2021-11-01      65196.930390        3890.085236    10.424167     42.420833
# 2021-12-01      79314.280940        4675.045226     7.497581     41.411290
#
# ...

# %%
predictors=weather.columns[~weather.columns.isin(['target', 'date'])]

# %%
predictors
# Out:
# Index(['en_requests (mj)', 'co2_emission (kg)', 'temperature', 'rel_humidity',
#        'solar_hour', 'wind_speed', 'rolling_2-en_requests (mj)',
#        'rolling_2-en_requests (mj)-pct', 'rolling_2-co2_emission (kg)',
#        'rolling_2-co2_emission (kg)-pct', 'rolling_2-temperature',
#        'rolling_2-temperature-pct', 'rolling_2-rel_humidity',
#        'rolling_2-rel_humidity-pct', 'rolling_2-solar_hour',
#        'rolling_2-solar_hour-pct', 'rolling_2-wind_speed',
#        'rolling_2-wind_speed-pct', 'month_avg_en_requests (mj)',
#        'day_avg_en_requests (mj)', 'month_avg_co2_emission (kg)',
#        'day_avg_co2_emission (kg)', 'month_avg_temperature',
#        'day_avg_temperature', 'month_avg_rel_humidity', 'day_avg_rel_humidity',
#        'month_avg_solar_hour', 'day_avg_solar_hour', 'month_avg_wind_speed',
#        'day_avg_wind_speed'],
#       dtype='object')

# %%
predictions = backtest(weather, rr, predictors)

# %%
mean_absolute_error(predictions['actual'], predictions['prediction'])
# Out:
# 15715.191306611541

# %%
predictions.sort_values('diff', ascending=False)
# Out:
#                   actual     prediction           diff
# date
# 2016-01-01  114648.99080   11653.122658  102995.868142
# 2015-03-01   45763.54108  122102.126924   76338.585844
# 2015-01-01  125343.16780   65547.565766   59795.602034
# 2015-02-01   77959.75638   21176.944990   56782.811390
# 2015-12-01  137131.91400  191340.954300   54209.040300
# ...                  ...            ...            ...
# 2019-08-01   20481.62488   22051.106033    1569.481153
# 2015-10-01   90737.80415   91461.286187     723.482037
# 2017-06-01   12860.45193   12236.399673     624.052257
# 2018-11-01  126905.39700  127043.376144     137.979144
# 2019-02-01   87742.97423   87666.972027      76.002203
#
# [105 rows x 3 columns]

# %%
weather.loc["2017-01-01":"2021-12-12"]
# Out:
#             en_requests (mj)  co2_emission (kg)  temperature  rel_humidity  \
# date
# 2017-01-01      124142.20840        6814.875550     4.889516     49.225806
# 2017-02-01      111000.95890        6167.294957     6.096875     60.642857
# 2017-03-01       67699.57813        4036.961378    12.178226     48.899194
# 2017-04-01       28129.40079        2039.636357    18.875000     36.679167
# 2017-05-01       10840.31231        1382.821603    27.028226     26.584677
# 2017-06-01       13214.68897        1927.137270    30.915000     19.500000
# 2017-07-01       12860.45193        1919.279500    31.031855     16.725806
# 2017-08-01       13572.25734        1916.671801    29.044758     15.673387
# 2017-09-01       11791.66205        1517.538933    25.795833     19.641667
# 2017-10-01       15138.30438        1277.882621    19.219758     25.125000
# 2017-11-01       34114.54915        2261.991611    13.123333     35.191667
# ...

# %%
predictions['diff'].round().value_counts()
# Out:
# 11293.0     2
# 24322.0     2
# 5677.0      1
# 1569.0      1
# 3083.0      1
#            ..
# 102996.0    1
# 54209.0     1
# 23937.0     1
# 723.0       1
# 26286.0     1
# Name: diff, Length: 103, dtype: int64

# %%
predictions['diff'].round().value_counts().sort_index()
# Out:
# 76.0        1
# 138.0       1
# 624.0       1
# 723.0       1
# 1569.0      1
#            ..
# 54209.0     1
# 56783.0     1
# 59796.0     1
# 76339.0     1
# 102996.0    1
# Name: diff, Length: 103, dtype: int64

# %%
predictions['diff'].round().value_counts().plot()
# Out:
# <AxesSubplot:>
